# %%
import __init__
import os, argparse, yaml, numpy as np
import sys
# sys.path.append("C:\\Users\\pojzi\\Programovanie\\bakalarka\\PointNeXt\\")
                
from torch import multiprocessing as mp
from examples.classification.train import main as train
from examples.classification.pretrain import main as pretrain
from openpoints.utils import EasyConfig, dist_utils, find_free_port, generate_exp_directory, resume_exp_directory, Wandb
import sys


# parser = argparse.ArgumentParser('S3DIS scene segmentation training')
# parser.add_argument('--cfg', type=str, required=True, help='config file')
# parser.add_argument('--profile', action='store_true', default=False, help='set to True to profile speed')
# args, opts = parser.parse_known_args()

opts = []

class Args:
    def __init__(self, cfg, profile):
        self.cfg = cfg
        self.profile = profile

args = Args(cfg="../../cfgs/modelnet40ply2048/pointnext-s.yaml", profile=False)
cfg = EasyConfig()

cfg.load(args.cfg, recursive=True)
# cfg.update(opts)
if cfg.seed is None:
    cfg.seed = np.random.randint(1, 10000)

# init distributed env first, since logger depends on the dist info.
cfg.rank, cfg.world_size, cfg.distributed, cfg.mp = dist_utils.get_dist_info(cfg)
cfg.sync_bn = cfg.world_size > 1

# init log dir
cfg.task_name = args.cfg.split('.')[-2].split('/')[-2]
cfg.exp_name = args.cfg.split('.')[-2].split('/')[-1]
tags = [
    cfg.task_name,  # task name (the folder of name under ./cfgs
    cfg.mode,
    cfg.exp_name,  # cfg file name
    f'ngpus{cfg.world_size}',
    f'seed{cfg.seed}',
]
opt_list = [] # for checking experiment configs from logging file
for i, opt in enumerate(opts):
    if 'rank' not in opt and 'dir' not in opt and 'root' not in opt and 'pretrain' not in opt and 'path' not in opt and 'wandb' not in opt and '/' not in opt:
        opt_list.append(opt)
cfg.root_dir = os.path.join(cfg.root_dir, cfg.task_name)
cfg.opts = '-'.join(opt_list)

# added here 
# cfg.mode = 'test'
if cfg.mode in ['resume', 'val', 'test']:
    resume_exp_directory(cfg, pretrained_path=cfg.pretrained_path)
    cfg.wandb.tags = [cfg.mode]
else:  # resume from the existing ckpt and reuse the folder.
    generate_exp_directory(cfg, tags, additional_id=os.environ.get('MASTER_PORT', None))
    cfg.wandb.tags = tags
os.environ["JOB_LOG_DIR"] = cfg.log_dir
cfg_path = os.path.join(cfg.run_dir, "cfg.yaml")
with open(cfg_path, 'w') as f:
    yaml.dump(cfg, f, indent=2)
    os.system('copy {} {}'.format(args.cfg, cfg.run_dir))

cfg.cfg_path = cfg_path
cfg.wandb.name = cfg.run_name

if cfg.mode == 'pretrain':
    main = pretrain
else:
    main = train

raise Exception('stop here')
# multi processing.
if cfg.mp:
    port = find_free_port()
    cfg.dist_url = f"tcp://localhost:{port}"
    print('using mp spawn for distributed training')
    mp.spawn(main, nprocs=cfg.world_size, args=(cfg, args.profile))
else:
    model = main(0, cfg, profile=args.profile)
# Out:
# launch mp with 1 GPUs, current rank: 0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10296\1140226224.py in <module>
#      74     main = train
#      75
# ---> 76 raise Exception('stop here')
#      77 # multi processing.
#      78 if cfg.mp:
#
# Exception: stop here

# %%
# %%capture

train_loader = main(0, cfg, profile=args.profile)
# Out:
# [04/17 21:50:20 ModelNet40Ply2048]: dist_url: tcp://localhost:8888
# dist_backend: nccl
# multiprocessing_distributed: False
# ngpus_per_node: 1
# world_size: 1
# launcher: mp
# local_rank: 0
# use_gpu: True
# seed: 5711
# epoch: 0
# epochs: 600
# ignore_index: None
# val_fn: validate
# deterministic: False
# sync_bn: False
# criterion_args:
#   NAME: SmoothCrossEntropy
#   label_smoothing: 0.2
# use_mask: False
# grad_norm_clip: 1
# layer_decay: 0
# step_per_update: 1
# start_epoch: 1
# sched_on_epoch: True
# wandb:
#   use_wandb: False
#   project: PointNeXt-ModelNet40Ply2048
#   tags: ['modelnet40ply2048', 'train', 'pointnext-s', 'ngpus1', 'seed5711']
#   name: modelnet40ply2048-train-pointnext-s-ngpus1-seed5711-20240417-213756-TRHc2zWkzDuE53x72ZkC5y
# use_amp: False
# use_voting: False
# val_freq: 1
# resume: False
# test: False
# finetune: False
# mode: train
# logname: None
# load_path: None
# print_freq: 10
# save_freq: -1
# root_dir: log/modelnet40ply2048
# ...

# %%
data = next(iter(train_loader))

# %%
pos = data['pos']
x = data['x']
y = data['y']

# %%
pos.shape
# Out:
# torch.Size([32, 1024, 3])

# %%
x.shape
# Out:
# torch.Size([32, 1024, 3])

# %%
y.shape
# Out:
# torch.Size([32])

# %%
# use matploblib to visualize the point cloud
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

first_pcl = pos[0].numpy()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(first_pcl[:, 0], first_pcl[:, 1], first_pcl[:, 2])
plt.show()

# %%
second_pcl = x[0].numpy()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(first_pcl[:, 0], first_pcl[:, 1], first_pcl[:, 2])
plt.show()

# %%
x[0].shape
# Out:
# torch.Size([1024, 3])

# %%
import os
import open3d as o3d
import numpy as np

class obj2pcl: 
    @staticmethod
    def convert(path, num_points=1000, ouput_name=None):
        if not os.path.exists(path):
            raise FileNotFoundError("The path does to the source .obj file does not exist")
        
        mesh = o3d.io.read_triangle_mesh(path)
        point_cloud = mesh.sample_points_uniformly(number_of_points=num_points)
        
        return point_cloud, np.asarray(point_cloud.points)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import os
from torch.utils.data import Dataset, DataLoader
import torch

class CustomDataset(Dataset):
    def __init__(self, path_to_data, num_points=1024, num_classes=5):
        if not os.path.exists(path_to_data):
            raise FileNotFoundError("The path does not exist")
        
        self.num_classes = num_classes
        self.num_points = 1024
        self.datadir = path_to_data
        self.absolute_path = os.path.join(os.getcwd(), self.datadir)
        self.labels = self.find_classes()
        self.data = self.create_data()
        
        print("Found {} classes".format(self.__len__()))
        
        # Create class-to-index mapping
        self.class_to_idx = {class_: idx for idx, class_ in enumerate(self.labels)}
            
    def find_classes(self):
        directories = os.listdir(self.datadir)
        return [x for x in directories if os.path.isdir(os.path.join(self.absolute_path, x))][:self.num_classes]
        
    def create_data(self):
        data = []
        for class_ in self.labels:
            obj_path = os.path.join(self.absolute_path, class_, class_ + '.obj')
            _, pc_array = obj2pcl.convert(obj_path, num_points=self.num_points)
            data.append(pc_array)
        return data
            
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        return {'pos': self.data[index].astype(np.float32), 
                'x': self.data[index].astype(np.float32),
                'y': self.class_to_idx[self.labels[index]]}

dest = os.path.join("../../../impact_recognition/data/neutral_images_3d")

# Create an instance of CustomDataset
dataset = CustomDataset(dest, num_classes=32)

# sampler = torch.utils.data.distributed.DistributedSampler(dataset, shuffle=True)
# Create a DataLoader
dataloader = DataLoader(dataset,
                        batch_size=32, 
                        shuffle=True, 
                        num_workers=0,
                        drop_last = True,
                        pin_memory=True)


# Print the class-to-index mapping
print("Class to Index Mapping:", dataset.class_to_idx)
# Out:
# Found 32 classes
# Class to Index Mapping: {'CFD-AF-200-228-N': 0, 'CFD-AF-201-060-N': 1, 'CFD-AF-202-122-N': 2, 'CFD-AF-203-077-N': 3, 'CFD-AF-204-067-N': 4, 'CFD-AF-205-155-N': 5, 'CFD-AF-206-079-N': 6, 'CFD-AF-207-023-N': 7, 'CFD-AF-208-003-N': 8, 'CFD-AF-209-006-N': 9, 'CFD-AF-210-050-N': 10, 'CFD-AF-211-066-N': 11, 'CFD-AF-212-097-N': 12, 'CFD-AF-213-126-N': 13, 'CFD-AF-214-139-N': 14, 'CFD-AF-215-70-N': 15, 'CFD-AF-216-106-N': 16, 'CFD-AF-217-155-N': 17, 'CFD-AF-218-157-N': 18, 'CFD-AF-219-106-N': 19, 'CFD-AF-220-107-N': 20, 'CFD-AF-221-147-N': 21, 'CFD-AF-222-134-N': 22, 'CFD-AF-223-183-N': 23, 'CFD-AF-224-026-N': 24, 'CFD-AF-225-141-N': 25, 'CFD-AF-226-251-N': 26, 'CFD-AF-227-207-N': 27, 'CFD-AF-228-173-N': 28, 'CFD-AF-229-160-N': 29, 'CFD-AF-230-193-N': 30, 'CFD-AF-231-357-N': 31}

# %%
next(iter(train_loader))['x'].dtype
# Out:
# torch.float32

# %%
next(iter(dataloader))['x'].dtype
# Out:
# torch.float32

# %%
dataset.class_to_idx
# Out:
# {'CFD-AF-200-228-N': 0,
#  'CFD-AF-201-060-N': 1,
#  'CFD-AF-202-122-N': 2,
#  'CFD-AF-203-077-N': 3,
#  'CFD-AF-204-067-N': 4,
#  'CFD-AF-205-155-N': 5,
#  'CFD-AF-206-079-N': 6,
#  'CFD-AF-207-023-N': 7,
#  'CFD-AF-208-003-N': 8,
#  'CFD-AF-209-006-N': 9,
#  'CFD-AF-210-050-N': 10,
#  'CFD-AF-211-066-N': 11,
#  'CFD-AF-212-097-N': 12,
#  'CFD-AF-213-126-N': 13,
#  'CFD-AF-214-139-N': 14,
#  'CFD-AF-215-70-N': 15,
#  'CFD-AF-216-106-N': 16,
#  'CFD-AF-217-155-N': 17,
#  'CFD-AF-218-157-N': 18,
#  'CFD-AF-219-106-N': 19,
#  'CFD-AF-220-107-N': 20,
#  'CFD-AF-221-147-N': 21,
#  'CFD-AF-222-134-N': 22,
#  'CFD-AF-223-183-N': 23,
#  'CFD-AF-224-026-N': 24,
#  'CFD-AF-225-141-N': 25,
#  'CFD-AF-226-251-N': 26,
#  'CFD-AF-227-207-N': 27,
#  'CFD-AF-228-173-N': 28,
#  'CFD-AF-229-160-N': 29,
#  'CFD-AF-230-193-N': 30,
#  'CFD-AF-231-357-N': 31}

# %%
iterator = iter(dataloader)

# Get the next batch
dic = next(iterator)

# %%
first_pcl.shape
# Out:
# torch.Size([1024, 3])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

first_pcl = dic['x'][0]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d', azim=30, elev=-50)
ax.scatter(first_pcl[:, 0], first_pcl[:, 1], first_pcl[:, 2])
plt.show()

# %%
from openpoints.utils import set_random_seed, save_checkpoint, load_checkpoint, load_checkpoint_inv, resume_checkpoint, setup_logger_dist, \
    cal_model_parm_nums, Wandb
from torch.utils.tensorboard import SummaryWriter
import os, logging, csv, numpy as np, wandb
from openpoints.models import build_model_from_cfg
from openpoints.optim import build_optimizer_from_cfg
from openpoints.scheduler import build_scheduler_from_cfg

from train import train_one_epoch


def train():  
    if cfg.distributed:
            if cfg.mp:
                cfg.rank = gpu
            dist.init_process_group(backend=cfg.dist_backend,
                                    init_method=cfg.dist_url,
                                    world_size=cfg.world_size,
                                    rank=cfg.rank)
            dist.barrier()
    # logger
    # print("settings up logger dist", cfg.log_path)
    # setup_logger_dist(cfg.log_path, cfg.rank, name=cfg.dataset.common.NAME)
    setup_logger_dist(None, cfg.rank, name=cfg.dataset.common.NAME)
    if cfg.rank == 0 :
        Wandb.launch(cfg, cfg.wandb.use_wandb)
        writer = SummaryWriter(log_dir=cfg.run_dir)
    else:
        writer = None
    set_random_seed(cfg.seed + cfg.rank, deterministic=cfg.deterministic)
    torch.backends.cudnn.enabled = True
#     logging.info(cfg)

    if not cfg.model.get('criterion_args', False):
        cfg.model.criterion_args = cfg.criterion_args

    model = build_model_from_cfg(cfg.model).to(cfg.rank)
    model_size = cal_model_parm_nums(model)
#     logging.info(model)
    logging.info('Number of params: %.4f M' % (model_size / 1e6))
    # criterion = build_criterion_from_cfg(cfg.criterion_args).cuda()
    if cfg.model.get('in_channels', None) is None:
        cfg.model.in_channels = cfg.model.encoder_args.in_channels

    if cfg.sync_bn:
        model = torch.nn.SyncBatchNorm.convert_sync_batchnorm(model)
        logging.info('Using Synchronized BatchNorm ...')
    if cfg.distributed:
        torch.cuda.set_device(gpu)
        model = nn.parallel.DistributedDataParallel(
            model.cuda(), device_ids=[cfg.rank], output_device=cfg.rank)
        logging.info('Using Distributed Data parallel ...')

    # optimizer & scheduler
    optimizer = build_optimizer_from_cfg(model, lr=cfg.lr, **cfg.optimizer)
    scheduler = build_scheduler_from_cfg(cfg, optimizer)
    
#     val_loader = DataLoader(dataset,
#                             batch_size=2, 
#                             shuffle=True, 
#                             num_workers=0,
#                             drop_last = True,
#                             pin_memory=True,
#                             split='val')


    dataset = CustomDataset(dest, num_classes=32)

    train_loader = DataLoader(dataset,
                        batch_size=32, 
                        shuffle=True, 
                        num_workers=0,
                        drop_last = True,
                        pin_memory=True)
    
    num_points = train_loader.dataset.num_points
    num_classes = train_loader.dataset.num_classes
    validate_fn = eval(cfg.get('val_fn', 'validate'))

    val_macc, val_oa, val_accs, best_val, macc_when_best, best_epoch = 0., 0., [], 0., 0., 0
    model.zero_grad()
    for epoch in range(0, 5):
        train_loss, train_macc, train_oa, _, _ = \
            train_one_epoch(model, train_loader,
                            optimizer, scheduler, epoch, cfg)
    
        is_best = False
        if epoch % cfg.val_freq == 0:
            val_macc, val_oa, val_accs, val_cm = validate_fn(
                model, val_loader, cfg)
            is_best = val_oa > best_val
            if is_best:
                best_val = val_oa
                macc_when_best = val_macc
                best_epoch = epoch
                logging.info(f'Find a better ckpt @E{epoch}')
                print_cls_results(val_oa, val_macc, val_accs, epoch, cfg)


    cfg.dataloader.num_workers = "0"

# %%
# %%capture

train()
# Out:
# [04/17 21:57:48 ModelNet40Ply2048]: radius: [[0.15], [0.15], [0.22499999999999998], [0.33749999999999997], [0.50625], [0.7593749999999999]],
#  nsample: [[32], [32], [32], [32], [32], [32]]
# [04/17 21:57:48 ModelNet40Ply2048]: NAME: ballquery
# normalize_dp: True
# radius: 0.15
# nsample: 32
# [04/17 21:57:48 ModelNet40Ply2048]: NAME: ballquery
# normalize_dp: True
# radius: 0.22499999999999998
# nsample: 32
# [04/17 21:57:48 ModelNet40Ply2048]: NAME: ballquery
# normalize_dp: True
# radius: 0.33749999999999997
# nsample: 32
# [04/17 21:57:48 ModelNet40Ply2048]: NAME: ballquery
# normalize_dp: True
# radius: 0.50625
# nsample: 32
# [04/17 21:57:48 ModelNet40Ply2048]: NAME: ballquery
# normalize_dp: True
# radius: None
# nsample: None
# [04/17 21:57:48 ModelNet40Ply2048]: Number of params: 1.3735 M
# [04/17 21:57:48 ModelNet40Ply2048]: Param groups = {
#   "decay": {
#     "weight_decay": 0.05,
#     "params": [
#       "encoder.encoder.0.0.convs.0.0.weight",
# ...
